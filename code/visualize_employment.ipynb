# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('gdrive/My Drive/Stemanities/data/ss13pus_no_na.csv')
df_employed = df[df['ESR'] == 1] #excludes armed forces (4)
df_unemployed = df[(df['ESR'] == 3) | (df['ESR'] == 6)]

# %%
df_employed.head()
# Out:
#     RAC1P  RAC2P  RAC3P  RACBLK  RACWHT  ...    SSP  SSIP  PUBCOV  HINS3  HINS4
# 0       2      2      2       1       0  ...    0.0   0.0       2      2      2
# 1       2      2      2       1       0  ...    0.0   0.0       2      2      2
# 4       2      2      2       1       0  ...  930.0   0.0       2      2      2
# 9       1      1      1       0       1  ...    0.0   0.0       2      2      2
# 10      1      1      1       0       1  ...    0.0   0.0       2      2      2
#
# [5 rows x 21 columns]

# %%
#Poverty
plt.hist(df_employed['POVPIP'])
plt.show()

# %%
plt.hist(df_unemployed['POVPIP'])
plt.show()

# %%
#Race
plt.hist(df_employed['RAC1P'])
plt.show()

# %%
plt.hist(df_unemployed['RAC1P'])
plt.show()

# %%
#Age
plt.hist(df_employed['AGEP'])
plt.show()

# %%
plt.hist(df_unemployed['AGEP'])
plt.show()

# %%
#Sex
plt.hist(df_employed['SEX'], bins=2)
plt.show()

# %%
#Sex
plt.hist(df_unemployed['SEX'], bins=2)
plt.show()

# %%
print('amt employed:' + str(len(df_employed.index)) + ', amt unemployed:' + str(len(df_unemployed.index)))
# Out:
# amt employed:1357594, amt unemployed:1029917
