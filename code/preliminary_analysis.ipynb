# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Load data

df = pd.read_csv('gdrive/My Drive/Stemanities/data/ss13pus_no_na.csv')

df_employed = df[df['ESR'] == 1] #excludes armed forces (4)
df_unemployed = df[(df['ESR'] == 3) | (df['ESR'] == 6)]

df_employed.head()
# Out:
#     RAC1P  RAC2P  RAC3P  RACBLK  RACWHT  ...    SSP  SSIP  PUBCOV  HINS3  HINS4
# 0       2      2      2       1       0  ...    0.0   0.0       2      2      2
# 1       2      2      2       1       0  ...    0.0   0.0       2      2      2
# 4       2      2      2       1       0  ...  930.0   0.0       2      2      2
# 9       1      1      1       0       1  ...    0.0   0.0       2      2      2
# 10      1      1      1       0       1  ...    0.0   0.0       2      2      2
#
# [5 rows x 21 columns]

# %%
# Histogram of Race

plt.hist(df['RAC1P'])
# Out:
# (array([1.907157e+06, 2.395580e+05, 2.011200e+04, 1.630000e+03,
#         0.000000e+00, 3.075000e+03, 1.193520e+05, 3.529000e+03,
#         7.945100e+04, 4.883400e+04]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <a list of 10 Patch objects>)

# %%
# Bar Graph of Race
race_freq = df['RAC1P'].value_counts()

df_race = pd.DataFrame({'Race':['White','Black','Native American','Asian', 'Native Hawaiian', 'Other', 'Multiracial']}, {'Amount':[ race_freq[1], race_freq[2], race_freq[3] + race_freq[4] + race_freq[5], race_freq[6], race_freq[7], race_freq[8], race_freq[9] ]})
df.plot.bar(x='White', y='Amount')

"""
           1 .White alone                             
           2 .Black or African American alone         
           3 .American Indian alone                   
           4 .Alaska Native alone                     
           5 .American Indian and Alaska Native tribes specified; or American
             .Indian or Alaska Native, not specified and no other races
           6 .Asian alone                             
           7 .Native Hawaiian and Other Pacific Islander alone
           8 .Some Other Race alone                   
           9 .Two or More Races           
"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1694         blocks = form_blocks(arrays, names, axes)
# -> 1695         mgr = BlockManager(blocks, axes)
#    1696         mgr._consolidate_inplace()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     142         if do_integrity_check:
# --> 143             self._verify_integrity()
#     144
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     344             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 345                 construction_error(tot_items, block.shape[1:], self.axes)
#     346         if len(self.items) != tot_items:
#
# ...

# %%
freq = df['RAC1P'].value_counts()
 
#print(race_freq[0], race_freq[1], race_freq[2] + race_freq[3] + race_freq[4], race_freq[5], race_freq[6], race_freq[7], race_freq[8]


print (freq)
print(freq[1])

for i in range(1,10):
  print (freq[i])
# Out:
# 1    1907157
# 2     239558
# 6     119352
# 8      79451
# 9      48834
# 3      20112
# 7       3529
# 5       3075
# 4       1630
# Name: RAC1P, dtype: int64
# 1907157
# 1907157
# 239558
# 20112
# 1630
# 3075
# 119352
# 3529
# 79451
# 48834

# %%
df_race = pd.DataFrame({'Race':['White','Black','Native American','Asian', 'Native Hawaiian', 'Other', 'Multiracial']}, {'Amount':[ race_freq[1], race_freq[2], race_freq[3] + race_freq[4] + race_freq[5], race_freq[6], race_freq[7], race_freq[8], race_freq[9] ]})
df.plot.bar(x='White', y='Amount')
